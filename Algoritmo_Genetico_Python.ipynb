# %%
import random
import numpy as np

# %%
T = 60                     #periodo
tamPopulacao = 10         #quantidade de individuos da população 
rotas = 3                  #quantidade de rotas
tipoVeiculos = 3           #tipos de veiculos
qntdVeiculos = [96,58,45]  #ft_b - veiculos disponiveis para cada tipo

K = [100, 45, 67]   #custo operacional por tipo de veiculo
S = 10             #custo social

#iniciando uma população aleatoria
populacao = []  

individuoPai = np.zeros((tipoVeiculos, rotas))
for b in range(tipoVeiculos):
    for r in range(rotas):
        individuoPai[b][r] = random.randint(0, qntdVeiculos[b])
populacao.append(individuoPai)

#cria um individuo, sorteando valores sem ultrapassar o individuoPai 
for i in range(tamPopulacao): 
    individuo = np.zeros((tipoVeiculos, rotas))
    for b in range(tipoVeiculos):
        for r in range(rotas):
            individuo[b][r] = random.randint(0, individuoPai[b][r])
    populacao.append(individuo)
    
    
#imprimindo a população
print("\n __Populacao aleatoria__")
for individuo in populacao:
    print(individuo, end="\n")
print("_"*20)


viavel = True

for i in range(tamPopulacao):
    print("Individuo ",(i+1))
    individuo = populacao[i] 
    for b in range(tipoVeiculos):
        soma=0
        for r in range(rotas):  
            soma = soma +  individuo[b][r]
        print("Foram enviados ", soma, "veiculos do tipo", b)

        H_br = np.zeros((tipoVeiculos, rotas))

        #checar se a soma de veiculos enviados nao ultrapassa a frota
        if soma > qntdVeiculos[b]:
            viavel=False
            break
        else:
            viavel=True
            for b in range(tipoVeiculos):
                for r in range(rotas):
                    if individuo[b][r]==0:
                        H_br[b][r]=0
                    else:
                        H_br[b][r] = T/individuo[b][r]
    print()
    if viavel:
        
        #custo operacional 
        co=0
        for b in range(tipoVeiculos):
            for r in range(rotas):
                co = co + (K[b] * (individuo[b][r]))

        cs=0                              
        #custo social
        for b in range(tipoVeiculos):
            for r in range(rotas):
                cs = cs + (S * (H_br[b][r]))               
                
        #fitness
        fitness = co + cs
        print("\nFitness: ", fitness)

    print("\n")
# Out:
#  __Populacao aleatoria__
# [[ 2. 84. 35.]
#  [ 1. 57. 14.]
#  [39. 22.  2.]]
# [[ 0. 17. 25.]
#  [ 0. 34. 14.]
#  [ 9. 14.  2.]]
# [[ 0. 57.  5.]
#  [ 1. 17.  7.]
#  [21. 19.  1.]]
# [[ 2. 74.  1.]
#  [ 1.  2.  9.]
#  [26.  4.  0.]]
# [[ 0. 21.  4.]
#  [ 1. 20.  6.]
#  [ 3.  7.  0.]]
# [[ 0.  4. 21.]
#  [ 1. 46. 11.]
#  [33. 11.  1.]]
# [[ 2. 42. 17.]
#  [ 0. 42. 11.]
#  [ 3.  3.  0.]]
# [[ 2. 41.  7.]
#  [ 1. 10. 13.]
#  [10. 15.  0.]]
# [[ 1. 51. 29.]
#  [ 1. 21.  5.]
#  [ 8.  1.  2.]]
# [[ 1.  6.  4.]
#  [ 1. 49. 13.]
#  [37.  5.  1.]]
# [[ 0. 84. 29.]
#  [ 0.  6. 14.]
#  [39. 21.  2.]]
# ____________________
# Individuo  1
# Foram enviados  121.0 veiculos do tipo 0
#
#
#
# Individuo  2
# Foram enviados  42.0 veiculos do tipo 0
# Foram enviados  48.0 veiculos do tipo 1
# Foram enviados  25.0 veiculos do tipo 2
#
#
# Fitness:  8564.322128851541
#
#
# Individuo  3
# Foram enviados  62.0 veiculos do tipo 0
# Foram enviados  25.0 veiculos do tipo 1
# Foram enviados  41.0 veiculos do tipo 2
#
#
# Fitness:  11583.685095090668
#
#
# Individuo  4
# Foram enviados  77.0 veiculos do tipo 0
# Foram enviados  12.0 veiculos do tipo 1
# Foram enviados  30.0 veiculos do tipo 2
#
#
# Fitness:  12297.851697851698
#
#
# Individuo  5
# Foram enviados  25.0 veiculos do tipo 0
# Foram enviados  27.0 veiculos do tipo 1
# Foram enviados  10.0 veiculos do tipo 2
#
#
# Fitness:  5579.285714285714
#
#
# Individuo  6
# Foram enviados  25.0 veiculos do tipo 0
# Foram enviados  58.0 veiculos do tipo 1
# Foram enviados  45.0 veiculos do tipo 2
#
#
# Fitness:  9643.887634105025
#
#
# Individuo  7
# Foram enviados  61.0 veiculos do tipo 0
# Foram enviados  53.0 veiculos do tipo 1
# Foram enviados  6.0 veiculos do tipo 2
#
#
# Fitness:  9705.411000763943
#
#
# Individuo  8
# Foram enviados  50.0 veiculos do tipo 0
# Foram enviados  24.0 veiculos do tipo 1
# Foram enviados  25.0 veiculos do tipo 2
#
#
# Fitness:  8961.502278209595
#
#
# Individuo  9
# Foram enviados  81.0 veiculos do tipo 0
# Foram enviados  27.0 veiculos do tipo 1
# Foram enviados  11.0 veiculos do tipo 2
#
#
# Fitness:  12408.025789626196
#
#
# Individuo  10
# Foram enviados  11.0 veiculos do tipo 0
# Foram enviados  63.0 veiculos do tipo 1
